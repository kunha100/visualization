# %%
import pandas as pd
df = pd.read_csv('/Users/kimgunha/visualization/02_activities/assignments/assignment_3/Children_death_in_Ontario.csv')
print (df)
# Out:
#     _id  Ref_Date Manner of Death  \
# 0     1      2013         Natural
# 1     2      2013        Homicide
# 2     3      2013        Accident
# 3     4      2013    Undetermined
# 4     5      2013         Suicide
# 5     6      2013         Natural
# 6     7      2013        Homicide
# 7     8      2013        Accident
# 8     9      2013    Undetermined
# 9    10      2013         Suicide
# 10   11      2014         Natural
# 11   12      2014        Homicide
# 12   13      2014        Accident
# 13   14      2014    Undetermined
# 14   15      2014         Suicide
# 15   16      2014         Natural
# 16   17      2014        Homicide
# 17   18      2014        Accident
# 18   19      2014    Undetermined
# 19   20      2014         Suicide
# 20   21      2015         Natural
# 21   22      2015        Homicide
# 22   23      2015        Accident
# 23   24      2015    Undetermined
# 24   25      2015         Suicide
# 25   26      2015         Natural
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_palette("colorblind")

deathgraph= sns.lineplot(data=df,
             x='Ref_Date',
             y='Value',hue='Manner of Death',style='STATISTICS')

deathgraph.set(
             xlabel = 'Year',
             ylabel='Death Count')
# Out:
# [Text(0.5, 0, 'Year'), Text(0, 0.5, 'Death Count')]
